# %% [markdown]
# # Test plotly

# %%
import plotly.express as px
import torch
import numpy as np
import pandas as pd

# %%
x = np.random.randn(100)
y = np.random.randn(100)
z = np.random.randn(100)
t = np.random.randint(0,5,100)
fig = px.scatter(x,y)

# %%
fig

# %%
px.scatter_3d(x=x,y=y,z=z)

# %%
px.scatter_3d(x=x,y=y,z=z, animation_frame=t)
